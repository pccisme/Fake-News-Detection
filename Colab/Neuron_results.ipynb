# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()

data = {}
titles = ['All', 'All - credit', 'All - speaker', 'All - party', 
            'All - state', 'All - context', 'All - job title', 'All - subject']
temp_mean_accuracies = [0.14266939252336447, 
                        0.14182242990654206, 
                        0.13138629283489095,
                        0.1320093457943925, 
                        0.13150311526479747, 
                        0.13640965732087226,
                        0.135708722741433, 
                        0.1343847352024922]

for i in range(len(titles)):
  data[titles[i]] = temp_mean_accuracies[i]

sorted_data = sorted(data.items(), key=lambda x: x[1])

features = []
mean_accuracies = []
for v1, v2 in sorted_data:
  features.append(v1)
  mean_accuracies.append(v2)

colors = ['royalblue','royalblue','royalblue','royalblue',
          'royalblue','royalblue','royalblue','indianred']
ax.barh(features, mean_accuracies, align='center', color=colors)
ax.set_title('Mean accuracies with val dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()

data = {}
titles = ['All', 'All - credit', 'All - speaker', 'All - party', 
            'All - state', 'All - context', 'All - job title', 'All - subject']
temp_best_accuracies = [0.20249221183800623,
                        0.20327102803738317,
                        0.14797507788161993,
                        0.16043613707165108,
                        0.14953271028037382, 
                        0.15498442367601245,
                        0.15031152647975077, 
                        0.15186915887850466]

for i in range(len(titles)):
  data[titles[i]] = temp_best_accuracies[i]

sorted_data = sorted(data.items(), key=lambda x: x[1])

features = []
best_accuracies = []
for v1, v2 in sorted_data:
  features.append(v1)
  best_accuracies.append(v2)

colors = ['royalblue','royalblue','royalblue','royalblue',
          'royalblue','royalblue','indianred','royalblue']
ax.barh(features, best_accuracies, align='center', color=colors)
ax.set_title('Best accuracies with val dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()

data = {}
titles = ['All', 'All - credit', 'All - speaker', 'All - party', 
            'All - state', 'All - context', 'All - job title', 'All - subject']
temp_test_accuracies = [0.14917127071823205, 
                        0.16179952644041043, 
                        0.17363851617995266, 
                        0.19179163378058406, 
                        0.16022099447513813, 
                        0.19652722967640096,
                        0.14759273875295975, 
                        0.1633780584056827]

for i in range(len(titles)):
  data[titles[i]] = temp_test_accuracies[i]

sorted_data = sorted(data.items(), key=lambda x: x[1])

features = []
test_accuracies = []
for v1, v2 in sorted_data:
  features.append(v1)
  test_accuracies.append(v2)

colors = ['royalblue','indianred','royalblue','royalblue',
          'royalblue','royalblue','royalblue','royalblue']
ax.barh(features, test_accuracies, align='center', color=colors)
ax.set_title('Best accuracies with test dataset')
plt.show()

# %%
# LIAR3_Neuron_ALL

# Best Accuracy: 0.20249221183800623
# Layer [(10,)]
# Activation: ['relu']
# Rate: ['adaptive']
# Mean Accuracy: 0.14266939252336447
# Test accuracy: 0.14917127071823205

# %%
# LIAR3_Neuron_remove_credit

# Best Accuracy: 0.20327102803738317
# Layer [(10, 10)]
# Activation: ['tanh']
# Rate: ['constant']
# Mean Accuracy: 0.14182242990654206

# Test accuracy: 0.16179952644041043

# %%
# LIAR3_Neuron_remove_speaker

# Best Accuracy: 0.14797507788161993
# Layer [(10, 10, 10)]
# Activation: ['tanh']
# Rate: ['constant']
# Mean Accuracy: 0.13138629283489095

# Test accuracy: 0.17363851617995266

# %%
# LIAR3_Neuron_remove_party

# Best Accuracy: 0.16043613707165108
# Layer [(10,)]
# Activation: ['relu']
# Rate: ['constant']
# Mean Accuracy: 0.1320093457943925

# Test accuracy: 0.19179163378058406

# %%
# LIAR3_Neuron_remove_state

# Best Accuracy: 0.14953271028037382
# Layer [(10,)]
# Activation: ['tanh']
# Rate: ['adaptive']
# Mean Accuracy: 0.13150311526479747

# Test accuracy: 0.16022099447513813

# %%
# LIAR3_Neuron_remove_context

# Best Accuracy: 0.15498442367601245
# Layer [(10,)]
# Activation: ['relu']
# Rate: ['constant']
# Mean Accuracy: 0.13640965732087226

# Test accuracy: 0.19652722967640096

# %%
# LIAR3_Neuron_remove_job_title.ipynb

# Best Accuracy: 0.15031152647975077
# Layer [(10,)]
# Activation: ['tanh']
# Rate: ['constant']
# Mean Accuracy: 0.135708722741433

# Test accuracy: 0.14759273875295975

# %%
# LIAR3_Neuron_remove_subject.ipynb

# Best Accuracy: 0.15186915887850466
# Layer [(10, 10)]
# Activation: ['tanh']
# Rate: ['constant']
# Mean Accuracy: 0.1343847352024922

# Test accuracy: 0.1633780584056827
