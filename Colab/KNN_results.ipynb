# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()

data = {}
titles = ['All', 'All - context', 'All - credit', 'All - job title', 
            'All - party', 'All - speaker', 'All - state', 'All - subject']
temp_mean_accuracies = [0.154595015576324, 0.15381619937694704, 0.15817757009345793, 
                   0.14929906542056073, 0.1559190031152648, 0.15443925233644862,
                   0.15171339563862926, 0.15288161993769467]

for i in range(len(titles)):
  data[titles[i]] = temp_mean_accuracies[i]

sorted_data = sorted(data.items(), key=lambda x: x[1])

features = []
mean_accuracies = []
for v1, v2 in sorted_data:
  features.append(v1)
  mean_accuracies.append(v2)

colors = ['royalblue','royalblue','royalblue','royalblue',
          'royalblue','indianred','royalblue','royalblue']
ax.barh(features, mean_accuracies, align='center', color=colors)
ax.set_title('Mean accuracies with val dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()

data = {}
titles = ['All', 'All - context', 'All - credit', 'All - job title', 
            'All - party', 'All - speaker', 'All - state', 'All - subject']
temp_best_accuracies = [0.16666666666666666, 0.16510903426791276, 0.17834890965732086, 
                   0.16510903426791276, 0.1658878504672897, 0.17289719626168223,
                   0.16822429906542055, 0.16433021806853582]

for i in range(len(titles)):
  data[titles[i]] = temp_best_accuracies[i]

sorted_data = sorted(data.items(), key=lambda x: x[1])

features = []
best_accuracies = []
for v1, v2 in sorted_data:
  features.append(v1)
  best_accuracies.append(v2)

colors = ['royalblue','royalblue','royalblue','royalblue',
          'indianred','royalblue','royalblue','royalblue']
ax.barh(features, best_accuracies, align='center', color=colors)
ax.set_title('Best accuracies with val dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcdefaults()
fig, ax = plt.subplots()

data = {}
titles = ['All', 'All - context', 'All - credit', 'All - job title', 
            'All - party', 'All - speaker', 'All - state', 'All - subject']
temp_test_accuracies = [0.1515390686661405, 0.15232833464877663, 0.16416732438831885, 
                   0.15864246250986583, 0.15548539857932123, 0.1712707182320442,
                   0.17363851617995266, 0.15074980268350435]

for i in range(len(titles)):
  data[titles[i]] = temp_test_accuracies[i]

sorted_data = sorted(data.items(), key=lambda x: x[1])

features = []
test_accuracies = []
for v1, v2 in sorted_data:
  features.append(v1)
  test_accuracies.append(v2)

colors = ['royalblue','indianred','royalblue','royalblue',
          'royalblue','royalblue','royalblue','royalblue']
ax.barh(features, test_accuracies, align='center', color=colors)
ax.set_title('Best accuracies with test dataset')
plt.show()

# %%
# KNN_ALL

# Best Accuracy: 0.16666666666666666
# num of neighbors: [3]
# KNN type: [1]
# Weight: ['uniform']
# Mean Accuracy: 0.154595015576324

# KNN test accuracy: 0.1515390686661405

# %%
# remove context

# Best Accuracy: 0.16510903426791276
# num of neighbors: [3]
# KNN type: [1]
# Weight: ['uniform']
# Mean Accuracy: 0.15381619937694704

# KNN test accuracy: 0.15232833464877663

# %%
# remove credit

# Best Accuracy: 0.17834890965732086
# num of neighbors: [3]
# KNN type: [2]
# Weight: ['uniform']
# Mean Accuracy: 0.15817757009345793

# KNN test accuracy: 0.16416732438831885

# %%
# remove job title

# Best Accuracy: 0.16510903426791276
# num of neighbors: [9]
# KNN type: [2]
# Weight: ['uniform']
# Mean Accuracy: 0.14929906542056073

# KNN test accuracy: 0.15864246250986583

# %%
# remove party

# Best Accuracy: 0.1658878504672897
# num of neighbors: [3]
# KNN type: [1]
# Weight: ['uniform']
# Mean Accuracy: 0.1559190031152648

# KNN test accuracy: 0.15548539857932123

# %%
# remove speaker

# Best Accuracy: 0.17289719626168223
# num of neighbors: [3]
# KNN type: [2]
# Weight: ['uniform']
# Mean Accuracy: 0.15443925233644862

# KNN test accuracy: 0.1712707182320442

# %%
# remove state

# Best Accuracy: 0.16822429906542055
# num of neighbors: [9]
# KNN type: [2]
# Weight: ['uniform']
# Mean Accuracy: 0.15171339563862926

# KNN test accuracy: 0.17363851617995266

# %%
# remove subject

# Best Accuracy: 0.16433021806853582
# num of neighbors: [9, 15]
# KNN type: [1, 1]
# Weight: ['uniform', 'uniform']
# Mean Accuracy: 0.15288161993769467

# KNN test accuracy: 0.15074980268350435
